# %%
import fitz
path = "paper1.pdf"
doc = fitz.open(path)

# %%
from PyQt6.QtWidgets import QApplication, QWidget, QVBoxLayout, QPushButton, QGraphicsView, QGraphicsScene, QFileDialog, QGraphicsRectItem,QRubberBand
page = doc.load_page(0)
page.get_pixmap

# %%
import os
from paddleocr import PaddleOCR
os.environ['KMP_DUPLICATE_LIB_OK']='True'
ocr = PaddleOCR(use_angle_cls=True, lang='en') 
tocimage_path = "C:\\Users\\Ashish.Madkaikar\\Desktop\\2024-05-04 21_53_32-Window.png"
result = ocr.ocr(tocimage_path, cls=True)
print(result)
pdf_file = "instruction-manual-fisher-et-eat-easy-e-valves-cl125-through-cl600-en-124782.pdf"
working_directory = os.getcwd() + "\\data\\"
FOLDER  = pdf_file.replace(".pdf","")
file_images_directory = f"{working_directory}\\{FOLDER}"
tocimage_path = "C:\\Users\\Ashish.Madkaikar\\Desktop\\2024-05-04 21_53_32-Window.png"
# def build_topics_from_TOC(tocimage_path):
#     topics = []
#     for i in os.listdir(file_images_directory):
#         img_path = f"{file_images_directory}\\{i}"
#         result = ocr.ocr(img_path, cls=True)
#         text = ""
#         for line in result:
#             text += line[1][0]
#         topics.append(text)
#     return topics

# topics=build_topics_from_TOC(tocimage_path)
# Out:
# [2024/05/04 22:14:20] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\Ashish.Madkaikar\\Anaconda3\\envs\\iitm\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/05/04 22:14:29] ppocr DEBUG: dt_boxes num : 17, elapsed : 3.126680374145508
# [2024/05/04 22:14:30] ppocr DEBUG: cls num  : 17, elapsed : 1.1842243671417236
# [2024/05/04 22:14:59] ppocr DEBUG: rec_res num  : 17, elapsed : 28.29442024230957
# [[[[[32.0, 19.0], [700.0, 21.0], [700.0, 56.0], [32.0, 54.0]], ('Table of Contents - Actuators', 0.9650254249572754)], [[[37.0, 84.0], [145.0, 84.0], [145.0, 105.0], [37.0, 105.0]], ('Features', 0.9861510992050171)], [[[33.0, 120.0], [198.0, 120.0], [198.0, 142.0], [33.0, 142.0]], ('Specifications', 0.9998801946640015)], [[[32.0, 154.0], [306.0, 156.0], [306.0, 177.0], [32.0, 175.0]], ('Available Configurations', 0.9954061508178711)], [[[28.0, 187.0], [123.0, 189.0], [122.0, 215.0], [27.0, 212.0]], ('. Tables', 0.9163522720336914)], [[[38.0, 227.0], [176.0, 227.0], [176.0, 248.0], [38.0, 248.0]], ('Dimensions', 0.999205470085144)], [[[37.0, 263.0], [334.0, 263.0], [334.0, 286.0], [37.0, 286.0]], ('Integral Instrument Mount', 0.9939372539520264)], [[[38.0, 300.0], [176.0, 300.0], [176.0, 321.0], [38.0, 321.0]], ('Accessories', 0.9991353750228882)], [[[34.0, 333.0], [277.0, 335.0], [276.0, 359.0], [34.0, 357.0]], ('Ordering Information.', 0.9602769017219543)], [[[42.0, 370.0], [310.0, 371.0], [310.0, 393.0], [41.0, 392.0]], ('Additional Specifications', 0.9987908005714417)], [[[36.0, 407.0], [390.0, 408.0], [390.0, 429.0], [36.0, 428.0]], ('Volumetric Casing Displacement', 0.9997465014457703)], [[[33.0, 444.0], [235.0, 444.0], [235.0, 465.0], [33.0, 465.0]], ('Actuator Weights', 0.9989752173423767)], [[[32.0, 480.0], [247.0, 480.0], [247.0, 501.0], [32.0, 501.0]], ('Thrust Capabilities', 0.9963993430137634)], [[[30.0, 512.0], [323.0, 513.0], [323.0, 537.0], [30.0, 536.0]], ('.Handwheel Specifications', 0.9946513175964355)], [[[32.0, 548.0], [293.0, 548.0], [293.0, 572.0], [32.0, 572.0]], ('Adjustable Travel Stops', 0.9992898106575012)], [[[33.0, 584.0], [178.0, 586.0], [178.0, 609.0], [32.0, 607.0]], ('Dimensions', 0.997157871723175)], [[[34.0, 622.0], [266.0, 622.0], [266.0, 643.0], [34.0, 643.0]], ('Educational Services', 0.9976004362106323)]]]

# %%
import os
from dotenv import load_dotenv
import glob 
from PIL import Image
import json
from paddleocr import PaddleOCR
load_dotenv()
def sanitize(word):
    return word.replace(".","").replace("-", "").strip()
def initialize_knowledge_map(topic):
   root_topic_input_location = get_root_topic_input_location(topic)
   root_topic_toc_image = "toc.png"
   root_topic_toc_image = f"{root_topic_input_location}{root_topic_toc_image}"
   return root_topic_toc_image

def get_topics_from_toc_image(root_topic_toc_image):
   ocr = PaddleOCR(use_angle_cls=True, lang='en') # need to run only once to download and load model into memory
   result = ocr.ocr(root_topic_toc_image, cls=True)
   topics = {}
   for idx in range(len(result)):
       res = result[idx]
       for line in res:
           topics[sanitize(line[1][0])] = ""
   return topics
def get_root_topic_input_location(topic):
   default_root_path = os.getenv('DEFAULT_LOCATION_FOR_TOPIC_COLLECTION')
   return f"{default_root_path}\{topic}"
def update_map_sub_topics(topics):
   for filename in glob.glob(f'{get_root_topic_input_location(topics)}/*.png'):
       toc = filename.split("/")[-1].split(".")[0] # strip path and ext from file name   
       if toc in topics.keys():
           sub_topics = get_topics_from_toc_image(filename)
           topics[toc] = sub_topics
   return topics
def persist_topics(topics):
   f = f"{get_root_topic_input_location(topic)}/topics.json"
   with open(f, 'w') as file:
       json.dump(topics, file)
       return f
# Out:
# [2024-06-10 17:54:30,728] [ WARNING] main.py:28 - Python-dotenv could not parse statement starting at line 1

# %%
def initialize_knowledge_map(root_topics):

   root_topic_input_location = get_root_topic_input_location(root_topics)
   root_topic_toc_image = "toc.png"
   root_topic_toc_image = f"{root_topic_input_location}{root_topic_toc_image}"
   return root_topic_toc_image
def get_root_topic_input_location(root_topics):
   default_root_path = os.getenv('DEFAULT_LOCATION_FOR_TOPIC_COLLECTION')
   return f"{default_root_path}\{root_topics}"

def persist_topics(topics,root_topics):
   f = f"{get_root_topic_input_location(root_topics)}/topics.json"
   with open(f, 'w') as file:
       json.dump(topics, file)
       return f
   
load_dotenv()
root_topics = "\Topics"
root_topic_input_location = get_root_topic_input_location(root_topics)
root_topic_toc_image = "toc.png"
root_topic_toc_image = f"{root_topic_input_location}\{root_topic_toc_image}"
# OCR EXTRACT ROOT LEVEL TOPICS
topics = get_topics_from_toc_image(root_topic_toc_image)
topics
# FIND TOCS FOR SUB-TOPICS IF ANY AND ADD TO THE MAP OF TOPICS 

# topics
# topic_json_file = persist_topics(topics)
# print(f"Topics persisted : {topic_json_file}")
# Out:
# [2024/06/11 06:45:57] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\Ashish.Madkaikar\\Anaconda3\\envs\\bulletin-generator\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/06/11 06:46:01] ppocr DEBUG: dt_boxes num : 60, elapsed : 0.6479909420013428
# [2024/06/11 06:46:01] ppocr DEBUG: cls num  : 60, elapsed : 0.33299684524536133
# [2024/06/11 06:46:07] ppocr DEBUG: rec_res num  : 60, elapsed : 6.076387405395508
# {'Contents': '',
#  'Introduction': '',
#  'Scope of Manual': '',
#  '1': '',
#  'Description': '',
#  'Specifications': '',
#  '3': '',
#  'Educational Services': '',
#  'Security': '',
#  'Installation': '',
#  '4': '',
#  'Special Instructions for "Safe Use" and Installations': '',
#  'in Hazardous Locations': '',
#  '5': '',
#  'Actuator Mounting': '',
#  'Power Requirements': '',
#  '7': '',
#  'Wiring Instructions': '',
#  'Confiquration': '',
#  '11': '',
#  'Control Method Configuration': '',
#  'Modbus Setup': '',
#  'Connecting Using the Fisher easyDrive': '',
#  'Configuration Software': '',
#  '12': '',
#  'Valve Type Configuration': '',
#  'Initial Setup': '',
#  '13': '',
#  'Calibration Instructions': '',
#  'Operational Verification': '',
#  '17': '',
#  'Troubleshooting': '',
#  'Maintenance': '',
#  '18': '',
#  'Disassembly': '',
#  '19': '',
#  'Assembly': '',
#  '20': '',
#  'Parts Ordering': '',
#  '22': '',
#  'Parts Kits': '',
#  'Parts List': '',
#  'Actuator Mounting Configuration': '',
#  '26': '',
#  'Appendix A  Modbus': '',
#  '27': '',
#  'Appendix B  Certificate of Conformance': '',
#  '32': ''}

# %%
def update_map_with_sub_topics(topics, root_topics):
   for filename in glob.glob(f'{get_root_topic_input_location(root_topics)}/**/*.png',  recursive=True):
       toc = filename.split("\\")[-2] # strip path and ext from file name   
       print(filename)
       print("filename", filename.split("\\")[-2])
       if toc in topics.keys():
           print("In ", filename)
           sub_topics = get_topics_from_toc_image(filename)
           topics[toc] = sub_topics
   return topics
# sanitized_topics = 
# for filename in glob.glob(f'{get_root_topic_input_location(root_topics)}/*.png'):
#     print(filename)
topics2 = update_map_with_sub_topics(topics, root_topics=root_topics)
display(topics2)
topic_json_file = persist_topics(topics2, root_topics=root_topics)
topic_json_file
# Out:
# C:\Users\Ashish.Madkaikar\OneDrive - Emerson\GenaAI IMP\SSV_Marketing\200R\\Topics\toc.png
# filename Topics
# C:\Users\Ashish.Madkaikar\OneDrive - Emerson\GenaAI IMP\SSV_Marketing\200R\\Topics\Specifications\toc.png
# filename Specifications
# In  C:\Users\Ashish.Madkaikar\OneDrive - Emerson\GenaAI IMP\SSV_Marketing\200R\\Topics\Specifications\toc.png
# [2024/06/10 18:49:25] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\Ashish.Madkaikar\\Anaconda3\\envs\\bulletin-generator\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\Ashish.Madkaikar/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/06/10 18:49:27] ppocr DEBUG: dt_boxes num : 51, elapsed : 0.451998233795166
# [2024/06/10 18:49:27] ppocr DEBUG: cls num  : 51, elapsed : 0.17400074005126953
# [2024/06/10 18:49:31] ppocr DEBUG: rec_res num  : 51, elapsed : 4.522424936294556
# {'Table of Contents  Actuators': '',
#  'Features': '',
#  'Specifications': {'Specifications  Actuators': '',
#   'Operating Temperature Range': '',
#   'Available Configurations': '',
#   'Signal Connections': '',
#   'Actuator Sizes': '',
#   'Standard Diaphragm Pressure Ranges': '',
#   'Construction Materials': '',
#   'Maximum Diaphragm Sizing Pressure': '',
#   'Material Temperature Capabilities': '',
#   'Maximum Diaphragm Casing Pressure': '',
#   'Available Actuator Configurations': '',
#   'Standard Operating Range': '',
#   'Compatible Fisher Valve Types and Sizes': '',
#   'Nominal Valve Shaft Rotation': '',
#   'Power Requirements': '',
#   'Valve Shaft Diameters': '',
#   'Stroking Time': '',
#   'Idle Current Draw': '',
#   'Diaphragm Casing Displacement': '',
#   'Conduit Connections': '',
#   'Piping or Tubing Connection Sizes': '',
#   'Mounting Positions': '',
#   'Travel': '',
#   'Maximum Travel': '',
#   'Travel stops': '',
#   'Output Indication': '',
#   ': Hazardous Area Approvals': '',
#   'Maximum Allowable Thrust': '',
#   'Torque': '',
#   'Nominal Stroke Speed': '',
#   'Control Signals': '',
#   'Hazardous Area Approvals': '',
#   'Mounting Type': '',
#   'Enclosure Rating': '',
#   'Approximate Weight': '',
#   'Duty Cycle': '',
#   'Options': '',
#   'Enclosure Material': ''},
#  'Available Configurations': '',
#  'Tables': '',
#  'Dimensions': '',
#  'Integral Instrument Mount': '',
#  'Accessories': '',
#  'Ordering Information': '',
#  'Additional Specifications': '',
#  'Volumetric Casing Displacement': '',
#  'Actuator Weights': '',
#  'Thrust Capabilities': '',
#  'Handwheel Specifications': '',
#  'Adjustable Travel Stops': '',
#  'Educational Services': ''}
# 'C:\\Users\\Ashish.Madkaikar\\OneDrive - Emerson\\GenaAI IMP\\SSV_Marketing\\200R\\\\Topics/topics.json'

# %%
for filename in glob.glob(f'{get_root_topic_input_location(root_topics)}/**/*.png', recursive=True):
    print(filename)
# Out:
# C:\Users\Ashish.Madkaikar\OneDrive - Emerson\GenaAI IMP\SSV_Marketing\200R\\Topics\toc.png
# C:\Users\Ashish.Madkaikar\OneDrive - Emerson\GenaAI IMP\SSV_Marketing\200R\\Topics\Specifications\toc.png

# %%
# Out:
# ('/Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections\\Topics',)

# %%
from pathlib import Path
from pdfminer.pdfparser import PDFParser, PDFSyntaxError
from pdfminer.pdfdocument import PDFDocument, PDFNoOutlines
import json
from dotenv import load_dotenv 
load_dotenv()

print(input_file_name,output_file_name )
# Out:
# C:\Users\Ashish.Madkaikar\OneDrive - Emerson\GenaAI IMP\SSV_Marketing\200R\Input - 200R Bulletin\200R IM Input.pdf C:\Users\Ashish.Madkaikar\OneDrive - Emerson\GenaAI IMP\SSV_Marketing\200R\Output - 200R Bulletin

# %%
import os
import json
from pathlib import Path
from pdfminer.pdfparser import PDFParser, PDFSyntaxError
from pdfminer.pdfdocument import PDFDocument, PDFNoOutlines
import json
import os
from dotenv import load_dotenv 
load_dotenv()
root_folder = os.environ["DEFAULT_LOCATION_FOR_TOPIC_COLLECTION"]
topics = r"Topics"
topics_folder = f"{root_folder}/{topics}"
input_file = "200R IM Input.pdf"
input_file_name = f"{os.environ['INPUT_FILES']}/{input_file}"
output_file_name = os.environ["OUTPUT_FILES"]
print(input_file_name, output_file_name)

def load_json(file_path):
   with open(file_path, 'r', encoding='utf-8') as file:
       return json.load(file)

def create_nested_dict(hierarchy_dict):
   def nested_insert(d, keys, value):
       for key in keys[:-1]:
           d = d.setdefault(key, {})
       d[keys[-1]] = value
       return d
   nested_dict = {}
   stack = []
   for key, level in hierarchy_dict.items():
       while len(stack) >= level:
           stack.pop()
       if stack:
           current_dict = nested_dict
           for parent in stack:
               current_dict = current_dict[parent]
           current_dict[key] = {}
           stack.append(key)
       else:
           nested_dict[key] = {}
           stack.append(key)
   return nested_dict

def create_folders_from_json(json_data, root_folder):
   def create_nested_folders(data, current_path):
       for key, value in data.items():
           new_path = os.path.join(current_path, key)
           os.makedirs(new_path, exist_ok=True)
           if isinstance(value, dict):
               create_nested_folders(value, new_path)
   if not os.path.exists(root_folder):
       os.makedirs(root_folder)
   create_nested_folders(json_data, root_folder)
   print("Folders created for Topics")


root_folder = os.environ["DEFAULT_LOCATION_FOR_TOPIC_COLLECTION"]
default_project = os.environ["DEFAULT_PROJECT"]
topics = r"topics"
topics_folder = f"{root_folder}/{default_project}/{topics}"
topics_folder, input_file_name
#create_folders_from_json(json_data, topics_folder):
## C:\Users\Ashish.Madkaikar\OneDrive - Emerson\GenaAI IMP\SSV_Marketing\200R\Topics
# Out:
# /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/input/200R IM Input.pdf /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/output
# ('/Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics',
#  '/Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/input/200R IM Input.pdf')

# %% [markdown]
# ## START MINING THE INPUT PDF DOCUMENT

# %%
def sanitize(word):
    return word.replace(".","").replace("-", "").replace("'", "").replace("\“", "").strip()

extracted_outlines = {}
# Extract the outlines into a dictionary 
with open(input_file_name, "rb") as fp:
    try:
        parser = PDFParser(fp)
        document = PDFDocument(parser)
        outlines = document.get_outlines()
       
        for (level, title, dest, a, se) in outlines:
             extracted_outlines[sanitize(title)] = level
             #print(level, title)
    except PDFNoOutlines:
        print("No outlines found.")
    except PDFSyntaxError:
        print("Corrupted PDF or non-PDF file.")
    finally:
        parser.close()

del extracted_outlines["Contents"]
# Based on the level create a nested dictionary and save to a topics.json file 
nested_dict = create_nested_dict(extracted_outlines)
display(nested_dict)
topics_json_file_path = f"{topics_folder}\\topics.json"
with open(topics_json_file_path, 'w') as f:
    json.dump(nested_dict, f)
# Out:
# {'Introduction': {'Scope of Manual': {},
#   'Description': {},
#   'Specifications': {},
#   'Educational Services': {}},
#  'Security': {},
#  'Installation': {'Special Instructions for “Safe Use” and Installations in Hazardous Locations': {},
#   'Actuator Mounting': {'Power Requirements': {}, 'Wiring Instructions': {}}},
#  'Configuration': {'Control Method Configuration': {}},
#  'Modbus Setup': {'Connecting Using the Fisher easy\xadDrive Configuration Software': {},
#   'Valve Type Configuration': {},
#   'Initial Setup': {},
#   'Calibration Instructions': {},
#   'Operational Verification': {}},
#  'Troubleshooting': {},
#  'Maintenance': {'Disassembly': {}, 'Assembly': {}},
#  'Parts Ordering': {},
#  'Parts Kits': {},
#  'Parts List': {},
#  'Actuator Mounting Configuration': {},
#  'Appendix A  Modbus': {},
#  'Appendix B  Certificate of Conformance': {}}

# %%
import json
import pandas as pd
from datasets import Dataset

# Load the JSON data
with open(topics_json_file_path, 'r') as f:
    data = json.load(f)

# Convert to a DataFrame
df = pd.DataFrame(data)
df

# # Concatenate the topic and content for training
# df['text'] = 'Topic: ' + df['topic'] + '\nContent: ' + df['content']

# # Create a Hugging Face Dataset
# dataset = Dataset.from_pandas(df[['text']])
# Out:
#                                                                                          Introduction  \
# Scope of Manual                                     {'1': 'Scope of Manual
# A
# This instruction manu...
# Description                                         {'1': 'Description
# The easy-Drive 2ooR electri...
# Specifications                                      {'4': 'Instruction Manual
# easy-Drive 200R
# D104...
# Educational Services                                {'2': 'Educational Services
# Emerson Educationa...
# 2                                                   Figure 1.Fisher easy-Drive200R\neasy-Drive\nX1913
# 1                                                                            Fisher" easy-Drive" 200R
# Special Instructions for “Safe Use” and Install...                                                NaN
# Actuator Mounting                                                                                 NaN
# 3                                                                                                 NaN
# Control Method Configuration                                                                      NaN
# Connecting Using the Fisher easy­Drive Configur...                                                NaN
# Valve Type Configuration                                                                          NaN
# Initial Setup                                                                                     NaN
# Calibration Instructions                                                                          NaN
# Operational Verification                                                                          NaN
# Disassembly                                                                                       NaN
# Assembly                                                                                          NaN
#
#                                                                                              Security  \
# Scope of Manual                                                                                   NaN
# Description                                                                                       NaN
# Specifications                                                                                    NaN
# Educational Services                                                                              NaN
# 2                                                                                                 NaN
# 1                                                   Security\nNOTICE\nPhysical security is an impo...
# Special Instructions for “Safe Use” and Install...                                                NaN
# Actuator Mounting                                                                                 NaN
# 3                                                                                                 NaN
# Control Method Configuration                                                                      NaN
# Connecting Using the Fisher easy­Drive Configur...                                                NaN
# Valve Type Configuration                                                                          NaN
# Initial Setup                                                                                     NaN
# Calibration Instructions                                                                          NaN
# Operational Verification                                                                          NaN
# Disassembly                                                                                       NaN
# Assembly                                                                                          NaN
#
#                                                                                          Installation  \
# Scope of Manual                                                                                   NaN
# Description                                                                                       NaN
# Specifications                                                                                    NaN
# Educational Services                                                                              NaN
# 2                                                   AWARNING\nFor explosion-proof applications, en...
# 1                                                   AWARNING\nAlways wear protective gloves, cloth...
# Special Instructions for “Safe Use” and Install...  {'1': 'Special Instructions for "Safe Use" and...
# Actuator Mounting                                   {'Power Requirements': {'2': 'Power
# 1.Connect1...
# 3                                                   AWARNING\nAvoid personal injury or property da...
# Control Method Configuration                                                                      NaN
# Connecting Using the Fisher easy­Drive Configur...                                                NaN
# Valve Type Configuration                                                                          NaN
# Initial Setup                                                                                     NaN
# Calibration Instructions                                                                          NaN
# Operational Verification                                                                          NaN
# Disassembly                                                                                       NaN
# Assembly                                                                                          NaN
#
#                                                    Configuration Modbus Setup  \
# Scope of Manual                                              NaN          NaN
# Description                                                  NaN          NaN
# Specifications                                               NaN          NaN
# Educational Services                                         NaN          NaN
# 2                                                            NaN          NaN
# 1                                                            NaN          NaN
# Special Instructions for “Safe Use” and Install...           NaN          NaN
# Actuator Mounting                                            NaN          NaN
# 3                                                            NaN          NaN
# Control Method Configuration                                  {}          NaN
# Connecting Using the Fisher easy­Drive Configur...           NaN           {}
# Valve Type Configuration                                     NaN           {}
# Initial Setup                                                NaN           {}
# Calibration Instructions                                     NaN           {}
# Operational Verification                                     NaN           {}
# Disassembly                                                  NaN          NaN
# Assembly                                                     NaN          NaN
#
#                                                     Troubleshooting  \
# Scope of Manual                                                 NaN
# Description                                                     NaN
# Specifications                                                  NaN
# Educational Services                                            NaN
# 2                                                               NaN
# 1                                                               NaN
# Special Instructions for “Safe Use” and Install...              NaN
# Actuator Mounting                                               NaN
# 3                                                               NaN
# Control Method Configuration                                    NaN
# Connecting Using the Fisher easy­Drive Configur...              NaN
# Valve Type Configuration                                        NaN
# Initial Setup                                                   NaN
# Calibration Instructions                                        NaN
# Operational Verification                                        NaN
# Disassembly                                                     NaN
# Assembly                                                        NaN
#
#                                                    Maintenance  \
# Scope of Manual                                            NaN
# Description                                                NaN
# Specifications                                             NaN
# Educational Services                                       NaN
# 2                                                          NaN
# 1                                                          NaN
# Special Instructions for “Safe Use” and Install...         NaN
# Actuator Mounting                                          NaN
# 3                                                          NaN
# Control Method Configuration                               NaN
# Connecting Using the Fisher easy­Drive Configur...         NaN
# Valve Type Configuration                                   NaN
# Initial Setup                                              NaN
# Calibration Instructions                                   NaN
# Operational Verification                                   NaN
# Disassembly                                                 {}
# Assembly                                                    {}
#
#                                                     Parts Ordering  \
# Scope of Manual                                                NaN
# Description                                                    NaN
# Specifications                                                 NaN
# Educational Services                                           NaN
# 2                                                              NaN
# 1                                                              NaN
# Special Instructions for “Safe Use” and Install...             NaN
# Actuator Mounting                                              NaN
# 3                                                              NaN
# Control Method Configuration                                   NaN
# Connecting Using the Fisher easy­Drive Configur...             NaN
# Valve Type Configuration                                       NaN
# Initial Setup                                                  NaN
# Calibration Instructions                                       NaN
# Operational Verification                                       NaN
# Disassembly                                                    NaN
# Assembly                                                       NaN
#
#                                                     Parts Kits  Parts List  \
# Scope of Manual                                            NaN         NaN
# Description                                                NaN         NaN
# Specifications                                             NaN         NaN
# Educational Services                                       NaN         NaN
# 2                                                          NaN         NaN
# 1                                                          NaN         NaN
# Special Instructions for “Safe Use” and Install...         NaN         NaN
# Actuator Mounting                                          NaN         NaN
# 3                                                          NaN         NaN
# Control Method Configuration                               NaN         NaN
# Connecting Using the Fisher easy­Drive Configur...         NaN         NaN
# Valve Type Configuration                                   NaN         NaN
# Initial Setup                                              NaN         NaN
# Calibration Instructions                                   NaN         NaN
# Operational Verification                                   NaN         NaN
# Disassembly                                                NaN         NaN
# Assembly                                                   NaN         NaN
#
#                                                     Actuator Mounting Configuration  \
# Scope of Manual                                                                 NaN
# Description                                                                     NaN
# Specifications                                                                  NaN
# Educational Services                                                            NaN
# 2                                                                               NaN
# 1                                                                               NaN
# Special Instructions for “Safe Use” and Install...                              NaN
# Actuator Mounting                                                               NaN
# 3                                                                               NaN
# Control Method Configuration                                                    NaN
# Connecting Using the Fisher easy­Drive Configur...                              NaN
# Valve Type Configuration                                                        NaN
# Initial Setup                                                                   NaN
# Calibration Instructions                                                        NaN
# Operational Verification                                                        NaN
# Disassembly                                                                     NaN
# Assembly                                                                        NaN
#
#                                                     Appendix A  Modbus  \
# Scope of Manual                                                    NaN
# Description                                                        NaN
# Specifications                                                     NaN
# Educational Services                                               NaN
# 2                                                                  NaN
# 1                                                                  NaN
# Special Instructions for “Safe Use” and Install...                 NaN
# Actuator Mounting                                                  NaN
# 3                                                                  NaN
# Control Method Configuration                                       NaN
# Connecting Using the Fisher easy­Drive Configur...                 NaN
# Valve Type Configuration                                           NaN
# Initial Setup                                                      NaN
# Calibration Instructions                                           NaN
# Operational Verification                                           NaN
# Disassembly                                                        NaN
# Assembly                                                           NaN
#
#                                                     Appendix B  Certificate of Conformance
# Scope of Manual                                                                        NaN
# Description                                                                            NaN
# Specifications                                                                         NaN
# Educational Services                                                                   NaN
# 2                                                                                      NaN
# 1                                                                                      NaN
# Special Instructions for “Safe Use” and Install...                                     NaN
# Actuator Mounting                                                                      NaN
# 3                                                                                      NaN
# Control Method Configuration                                                           NaN
# Connecting Using the Fisher easy­Drive Configur...                                     NaN
# Valve Type Configuration                                                               NaN
# Initial Setup                                                                          NaN
# Calibration Instructions                                                               NaN
# Operational Verification                                                               NaN
# Disassembly                                                                            NaN
# Assembly                                                                               NaN

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from datasets) (1.26.4)
# Collecting pyarrow>=12.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets)
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from datasets) (2.2.2)
# Collecting requests>=2.32.1 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.9.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from datasets) (0.23.0)
# Requirement already satisfied: packaging in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from datasets) (6.0.1)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Using cached frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Using cached multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Using cached yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from requests>=2.32.1->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from requests>=2.32.1->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.19.2-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading aiohttp-3.9.5-cp312-cp312-macosx_11_0_arm64.whl (392 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.4/392.4 kB 7.6 MB/s eta 0:00:00a 0:00:01
# Downloading pyarrow-16.1.0-cp312-cp312-macosx_11_0_arm64.whl (26.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 3.7 MB/s eta 0:00:0000:0100:01
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.6 MB/s eta 0:00:00
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached xxhash-3.4.1-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
# Using cached multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Using cached yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl (79 kB)
# Installing collected packages: xxhash, requests, pyarrow-hotfix, pyarrow, multidict, frozenlist, dill, attrs, yarl, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 attrs-23.2.0 datasets-2.19.2 dill-0.3.8 frozenlist-1.4.1 multidict-6.0.5 multiprocess-0.70.16 pyarrow-16.1.0 pyarrow-hotfix-0.6 requests-2.32.3 xxhash-3.4.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# pip install datasets

# %% [markdown]
# ## Load the json file and create topic folders recursively

# %%
json_data = load_json(f'{topics_folder}\\topics.json')
create_folders_from_json(json_data, topics_folder)
    #
# Out:
# Folders created for Topics

# %% [markdown]
# ## Perform OCR on all cropped topics and save as text -
# ### TODO
#     1. update the json file with Keys and OCR text
#     2. create embeddings and store in vectorstore for search

# %%
from OCRManager import perform_ocr_on_images
from paddleocr import PaddleOCR,draw_ocr
ocr = PaddleOCR(use_angle_cls=True, lang='en')
def perform_ocr_on_images(root_dir,ocr):
    # ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Initialize PaddleOCR
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(subdir, file)
                print("Topic : ", subdir)
                result = ocr.ocr(file_path, cls=True)
                ocr_text = '\n'.join([line[1][0] for line in result[0]])
                
                txt_filename = os.path.splitext(file_path)[0] + '.txt'
                with open(txt_filename, 'w') as txt_file:
                    print("processing ", txt_filename)
                    txt_file.write(ocr_text)
                print(f'OCR completed for {file_path}. Text saved to {txt_filename}.')

perform_ocr_on_images(topics_folder, ocr)
# Out:
# [2024/06/13 12:50:46] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Security
# [2024/06/13 12:50:47] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.2437419891357422
# [2024/06/13 12:50:47] ppocr DEBUG: cls num  : 18, elapsed : 0.07126379013061523
# [2024/06/13 12:50:53] ppocr DEBUG: rec_res num  : 18, elapsed : 6.198970079421997
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Security/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Security/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Security/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction
# [2024/06/13 12:50:54] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2010350227355957
# [2024/06/13 12:50:54] ppocr DEBUG: cls num  : 3, elapsed : 0.01116490364074707
# [2024/06/13 12:50:54] ppocr DEBUG: rec_res num  : 3, elapsed : 0.43653202056884766
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/2.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/2.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/2.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction
# [2024/06/13 12:50:54] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.036561012268066406
# [2024/06/13 12:50:54] ppocr DEBUG: cls num  : 1, elapsed : 0.004403829574584961
# [2024/06/13 12:50:54] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09850502014160156
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Scope of Manual
# [2024/06/13 12:50:54] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.06038498878479004
# [2024/06/13 12:50:54] ppocr DEBUG: cls num  : 8, elapsed : 0.029656171798706055
# [2024/06/13 12:50:57] ppocr DEBUG: rec_res num  : 8, elapsed : 3.155663251876831
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Scope of Manual/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Scope of Manual/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Scope of Manual/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications
# [2024/06/13 12:50:58] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.22616195678710938
# [2024/06/13 12:50:58] ppocr DEBUG: cls num  : 30, elapsed : 0.11592721939086914
# [2024/06/13 12:51:05] ppocr DEBUG: rec_res num  : 30, elapsed : 6.835085153579712
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/4.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/4.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/4.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications
# [2024/06/13 12:51:05] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.03223013877868652
# [2024/06/13 12:51:05] ppocr DEBUG: cls num  : 5, elapsed : 0.019788026809692383
# [2024/06/13 12:51:07] ppocr DEBUG: rec_res num  : 5, elapsed : 2.2477078437805176
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/2.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/2.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/2.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications
# [2024/06/13 12:51:07] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.08697009086608887
# [2024/06/13 12:51:07] ppocr DEBUG: cls num  : 24, elapsed : 0.08904409408569336
# [2024/06/13 12:51:10] ppocr DEBUG: rec_res num  : 24, elapsed : 3.0500669479370117
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/3.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/3.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/3.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications
# [2024/06/13 12:51:10] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.21878504753112793
# [2024/06/13 12:51:11] ppocr DEBUG: cls num  : 39, elapsed : 0.14805030822753906
# [2024/06/13 12:51:14] ppocr DEBUG: rec_res num  : 39, elapsed : 3.8533010482788086
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services
# [2024/06/13 12:51:14] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.04120683670043945
# [2024/06/13 12:51:14] ppocr DEBUG: cls num  : 5, elapsed : 0.019065141677856445
# [2024/06/13 12:51:15] ppocr DEBUG: rec_res num  : 5, elapsed : 0.7963986396789551
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services/2.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services/2.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services/2.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services
# [2024/06/13 12:51:16] ppocr DEBUG: dt_boxes num : 88, elapsed : 0.23772525787353516
# [2024/06/13 12:51:16] ppocr DEBUG: cls num  : 88, elapsed : 0.3312101364135742
# [2024/06/13 12:51:25] ppocr DEBUG: rec_res num  : 88, elapsed : 8.854426860809326
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Description
# [2024/06/13 12:51:25] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.06370210647583008
# [2024/06/13 12:51:25] ppocr DEBUG: cls num  : 8, elapsed : 0.0315248966217041
# [2024/06/13 12:51:29] ppocr DEBUG: rec_res num  : 8, elapsed : 3.7536799907684326
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Description/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Description/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Description/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation
# [2024/06/13 12:51:29] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.11304020881652832
# [2024/06/13 12:51:29] ppocr DEBUG: cls num  : 13, elapsed : 0.051949262619018555
# [2024/06/13 12:51:35] ppocr DEBUG: rec_res num  : 13, elapsed : 5.888983249664307
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/2.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/2.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/2.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation
# [2024/06/13 12:51:35] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.10400080680847168
# [2024/06/13 12:51:35] ppocr DEBUG: cls num  : 10, elapsed : 0.03803133964538574
# [2024/06/13 12:51:39] ppocr DEBUG: rec_res num  : 10, elapsed : 4.264366149902344
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/3.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/3.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/3.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation
# [2024/06/13 12:51:39] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.08813619613647461
# [2024/06/13 12:51:39] ppocr DEBUG: cls num  : 10, elapsed : 0.03831195831298828
# [2024/06/13 12:51:44] ppocr DEBUG: rec_res num  : 10, elapsed : 4.330813884735107
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Special Instructions for “Safe Use” and Installations in Hazardous Locations
# [2024/06/13 12:51:44] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.12945199012756348
# [2024/06/13 12:51:44] ppocr DEBUG: cls num  : 14, elapsed : 0.05281519889831543
# [2024/06/13 12:51:50] ppocr DEBUG: rec_res num  : 14, elapsed : 6.714385986328125
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Special Instructions for “Safe Use” and Installations in Hazardous Locations/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Special Instructions for “Safe Use” and Installations in Hazardous Locations/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Special Instructions for “Safe Use” and Installations in Hazardous Locations/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting
# [2024/06/13 12:51:51] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.18273377418518066
# [2024/06/13 12:51:51] ppocr DEBUG: cls num  : 16, elapsed : 0.06150031089782715
# [2024/06/13 12:51:56] ppocr DEBUG: rec_res num  : 16, elapsed : 5.5446131229400635
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/2.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/2.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/2.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting
# [2024/06/13 12:51:57] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.23589611053466797
# [2024/06/13 12:51:57] ppocr DEBUG: cls num  : 24, elapsed : 0.0928182601928711
# [2024/06/13 12:52:04] ppocr DEBUG: rec_res num  : 24, elapsed : 7.558470010757446
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Wiring Instructions
# [2024/06/13 12:52:04] ppocr DEBUG: dt_boxes num : 38, elapsed : 0.2320868968963623
# [2024/06/13 12:52:05] ppocr DEBUG: cls num  : 38, elapsed : 0.1440274715423584
# [2024/06/13 12:52:12] ppocr DEBUG: rec_res num  : 38, elapsed : 7.435635805130005
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Wiring Instructions/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Wiring Instructions/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Wiring Instructions/1.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements
# [2024/06/13 12:52:12] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.06354784965515137
# [2024/06/13 12:52:12] ppocr DEBUG: cls num  : 4, elapsed : 0.015668869018554688
# [2024/06/13 12:52:14] ppocr DEBUG: rec_res num  : 4, elapsed : 1.4110782146453857
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/2.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/2.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/2.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements
# [2024/06/13 12:52:14] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.07205700874328613
# [2024/06/13 12:52:14] ppocr DEBUG: cls num  : 4, elapsed : 0.015890836715698242
# [2024/06/13 12:52:15] ppocr DEBUG: rec_res num  : 4, elapsed : 1.3149902820587158
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/3.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/3.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/3.txt.
# Topic :  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements
# [2024/06/13 12:52:15] ppocr DEBUG: dt_boxes num : 32, elapsed : 0.23310399055480957
# [2024/06/13 12:52:15] ppocr DEBUG: cls num  : 32, elapsed : 0.12201285362243652
# [2024/06/13 12:52:22] ppocr DEBUG: rec_res num  : 32, elapsed : 6.27862811088562
# processing  /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/1.txt
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/1.png. Text saved to /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/1.txt.

# %% [markdown]
# ## Once all image tagging is done to Topics
# #### 1. Read the topics.json and update

# %%
from OCRManager import perform_ocr_on_images
from paddleocr import PaddleOCR,draw_ocr
ocr = PaddleOCR(use_angle_cls=True, lang='en')

topics_json_file_path = f"{topics_folder}\\topics.json"

def update_nested_dict(nested_dict, keys, value):
    """Update nested dictionary with OCR text."""
    for key in keys[:-1]:
        nested_dict = nested_dict.setdefault(key, {})
    nested_dict[keys[-1]] = value
def perform_ocr_on_images(root_dir, json_file_path):
    ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Initialize PaddleOCR

    # Load existing data from JSON file
    if os.path.exists(json_file_path):
        with open(json_file_path, 'r') as json_file:
            nested_dict = json.load(json_file)
    else:
        nested_dict = {}

    for subdir, _, files in os.walk(root_dir):
        # Calculate relative path from root directory and split it into parts
        relative_path = os.path.relpath(subdir, root_dir).split(os.sep)
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(subdir, file)
                result = ocr.ocr(file_path, cls=True)
                ocr_text = '\n'.join([line[1][0] for line in result[0]])
                file_key = os.path.splitext(file)[0]
                update_nested_dict(nested_dict, relative_path + [file_key], ocr_text)
                print(f'OCR completed for {file_path}. Text updated in nested dictionary.')

    # Save updated data back to JSON file
    with open(json_file_path, 'w') as json_file:
        json.dump(nested_dict, json_file, indent=4)

    return nested_dict

ocr_data = perform_ocr_on_images(topics_folder, topics_json_file_path)
print(ocr_data)
# Out:
# [2024/06/13 13:16:18] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/06/13 13:16:18] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/06/13 13:16:19] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/Users/ashishmadkaikar/miniforge3/envs/bulletin-generator/lib/python3.12/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/Users/ashishmadkaikar/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/06/13 13:16:19] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.23046088218688965
# [2024/06/13 13:16:19] ppocr DEBUG: cls num  : 18, elapsed : 0.0688943862915039
# [2024/06/13 13:16:26] ppocr DEBUG: rec_res num  : 18, elapsed : 6.08284592628479
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Security/1.png. Text updated in nested dictionary.
# [2024/06/13 13:16:26] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.20720386505126953
# [2024/06/13 13:16:26] ppocr DEBUG: cls num  : 3, elapsed : 0.011096000671386719
# [2024/06/13 13:16:26] ppocr DEBUG: rec_res num  : 3, elapsed : 0.43720078468322754
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/2.png. Text updated in nested dictionary.
# [2024/06/13 13:16:26] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0360720157623291
# [2024/06/13 13:16:26] ppocr DEBUG: cls num  : 1, elapsed : 0.00416111946105957
# [2024/06/13 13:16:26] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10411810874938965
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/1.png. Text updated in nested dictionary.
# [2024/06/13 13:16:26] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.05994820594787598
# [2024/06/13 13:16:26] ppocr DEBUG: cls num  : 8, elapsed : 0.030369997024536133
# [2024/06/13 13:16:30] ppocr DEBUG: rec_res num  : 8, elapsed : 3.169504165649414
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Scope of Manual/1.png. Text updated in nested dictionary.
# [2024/06/13 13:16:30] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.22857999801635742
# [2024/06/13 13:16:30] ppocr DEBUG: cls num  : 30, elapsed : 0.11404919624328613
# [2024/06/13 13:16:37] ppocr DEBUG: rec_res num  : 30, elapsed : 6.902354955673218
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/4.png. Text updated in nested dictionary.
# [2024/06/13 13:16:37] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.031013011932373047
# [2024/06/13 13:16:37] ppocr DEBUG: cls num  : 5, elapsed : 0.018579959869384766
# [2024/06/13 13:16:39] ppocr DEBUG: rec_res num  : 5, elapsed : 2.184512138366699
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/2.png. Text updated in nested dictionary.
# [2024/06/13 13:16:39] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.08585381507873535
# [2024/06/13 13:16:39] ppocr DEBUG: cls num  : 24, elapsed : 0.09098315238952637
# [2024/06/13 13:16:42] ppocr DEBUG: rec_res num  : 24, elapsed : 3.077946901321411
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/3.png. Text updated in nested dictionary.
# [2024/06/13 13:16:43] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.21998381614685059
# [2024/06/13 13:16:43] ppocr DEBUG: cls num  : 39, elapsed : 0.14827466011047363
# [2024/06/13 13:16:47] ppocr DEBUG: rec_res num  : 39, elapsed : 3.9244561195373535
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Specifications/1.png. Text updated in nested dictionary.
# [2024/06/13 13:16:47] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.04284811019897461
# [2024/06/13 13:16:47] ppocr DEBUG: cls num  : 5, elapsed : 0.018647193908691406
# [2024/06/13 13:16:48] ppocr DEBUG: rec_res num  : 5, elapsed : 0.8165209293365479
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services/2.png. Text updated in nested dictionary.
# [2024/06/13 13:16:48] ppocr DEBUG: dt_boxes num : 88, elapsed : 0.2363598346710205
# [2024/06/13 13:16:48] ppocr DEBUG: cls num  : 88, elapsed : 0.33533811569213867
# [2024/06/13 13:16:57] ppocr DEBUG: rec_res num  : 88, elapsed : 8.914782047271729
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Educational Services/1.png. Text updated in nested dictionary.
# [2024/06/13 13:16:57] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.061575889587402344
# [2024/06/13 13:16:57] ppocr DEBUG: cls num  : 8, elapsed : 0.03061366081237793
# [2024/06/13 13:17:01] ppocr DEBUG: rec_res num  : 8, elapsed : 3.7105512619018555
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Introduction/Description/1.png. Text updated in nested dictionary.
# [2024/06/13 13:17:01] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.11253905296325684
# [2024/06/13 13:17:01] ppocr DEBUG: cls num  : 13, elapsed : 0.04996848106384277
# [2024/06/13 13:17:07] ppocr DEBUG: rec_res num  : 13, elapsed : 5.898971080780029
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/2.png. Text updated in nested dictionary.
# [2024/06/13 13:17:07] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.10394716262817383
# [2024/06/13 13:17:07] ppocr DEBUG: cls num  : 10, elapsed : 0.03838014602661133
# [2024/06/13 13:17:11] ppocr DEBUG: rec_res num  : 10, elapsed : 4.291515111923218
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/3.png. Text updated in nested dictionary.
# [2024/06/13 13:17:12] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.08711981773376465
# [2024/06/13 13:17:12] ppocr DEBUG: cls num  : 10, elapsed : 0.03854703903198242
# [2024/06/13 13:17:16] ppocr DEBUG: rec_res num  : 10, elapsed : 4.343691825866699
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/1.png. Text updated in nested dictionary.
# [2024/06/13 13:17:16] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.12582015991210938
# [2024/06/13 13:17:16] ppocr DEBUG: cls num  : 14, elapsed : 0.05408596992492676
# [2024/06/13 13:17:23] ppocr DEBUG: rec_res num  : 14, elapsed : 6.685873746871948
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Special Instructions for “Safe Use” and Installations in Hazardous Locations/1.png. Text updated in nested dictionary.
# [2024/06/13 13:17:23] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.1825573444366455
# [2024/06/13 13:17:23] ppocr DEBUG: cls num  : 16, elapsed : 0.060288190841674805
# [2024/06/13 13:17:29] ppocr DEBUG: rec_res num  : 16, elapsed : 5.558341979980469
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/2.png. Text updated in nested dictionary.
# [2024/06/13 13:17:29] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.23392391204833984
# [2024/06/13 13:17:29] ppocr DEBUG: cls num  : 24, elapsed : 0.09052753448486328
# [2024/06/13 13:17:37] ppocr DEBUG: rec_res num  : 24, elapsed : 7.56146502494812
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/1.png. Text updated in nested dictionary.
# [2024/06/13 13:17:37] ppocr DEBUG: dt_boxes num : 38, elapsed : 0.23302006721496582
# [2024/06/13 13:17:37] ppocr DEBUG: cls num  : 38, elapsed : 0.1426253318786621
# [2024/06/13 13:17:44] ppocr DEBUG: rec_res num  : 38, elapsed : 7.441464900970459
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Wiring Instructions/1.png. Text updated in nested dictionary.
# [2024/06/13 13:17:44] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.06292009353637695
# [2024/06/13 13:17:44] ppocr DEBUG: cls num  : 4, elapsed : 0.015549898147583008
# [2024/06/13 13:17:46] ppocr DEBUG: rec_res num  : 4, elapsed : 1.41178297996521
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/2.png. Text updated in nested dictionary.
# [2024/06/13 13:17:46] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.07268595695495605
# [2024/06/13 13:17:46] ppocr DEBUG: cls num  : 4, elapsed : 0.015493154525756836
# [2024/06/13 13:17:47] ppocr DEBUG: rec_res num  : 4, elapsed : 1.317199945449829
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/3.png. Text updated in nested dictionary.
# [2024/06/13 13:17:48] ppocr DEBUG: dt_boxes num : 32, elapsed : 0.23155498504638672
# [2024/06/13 13:17:48] ppocr DEBUG: cls num  : 32, elapsed : 0.12118649482727051
# [2024/06/13 13:17:54] ppocr DEBUG: rec_res num  : 32, elapsed : 6.32646918296814
# OCR completed for /Users/ashishmadkaikar/code/python/bulletin-generator/topic_collections/200R/topics/Installation/Actuator Mounting/Power Requirements/1.png. Text updated in nested dictionary.
# {'Introduction': {'Scope of Manual': {'1': 'Scope of Manual\nA\nThis instruction manual provides installation, maintenance, and parts information for the easy-Drive.\n200R.Do not install, operate, or maintain an easy-Drive 2o0R without being fully trained and qualified in\nvalve, actuator, and accessory installation, operation, and maintenance.To avoid personal injury or\nproperty damage, it is important to carefully read, understand, and follow all the contents of this.\nmanual, including all safety cautions and warnings. If you have any questions about these instructions,\ncontact your Emerson sales officebefore proceeding..'}, 'Description': {'1': 'Description\nThe easy-Drive 2ooR electric rotary actuators are used on rotary-shaft valve bodies for throttling or on-off applications\nThe 200R has an ISO 5211 mating interface that allows installation to non-Fisher valves. Style F mounting is available\nfor coupling with Fisher rotaryvalves.This actuator is ideal for use on pressure and flow control applications for Fisher\nVee-Ball NPS 1-6,HPBV NPS 2-4 and non-Fisher 90rotaryvalves with 9 mm,11 mm,14 mm,or 19 mm square shaft\nconnections, and 5/8-inch or 3/4-inch splined shaft connections. In applications that require a known loss of power\nposition, an RPU-100 can be used to drive the easy-Drive actuator open or closed.Consult the easy-Drive RPU-100\nInstruction Manual (D104551X012)'}, 'Specifications': {'4': "Instruction Manual\neasy-Drive 200R\nD104742X012\nApril 2024\nSpecifications\nTable 1 lists specifications for the easy-Drive 2o0R. Some of the specifications for a given actuator as it originally.\ncomes from the factory are stamped on a nameplate located on the lower actuator enclosure\nEducational Services\nEmerson Educational Services\nPhone: 1-800-338-8158\nE-mail: education@emerson.com\nemerson.com/mytraining\nSecurity\nNOTICE\nPhysical security is an important part of any security program and is fundamental to protecting your system..\nUnauthorized personnel may potentially cause significant damage to and/or misconfiguration of end users' equipment.\nThis could be intentional or unintentional and must be protected against by restricting access to unauthorized personnel in\nyour facility.\n If unsecured, any device in the field is vulnerable to a physical attack; safety and security procedures must include\nmitigation by physical security controls..\nThe easy-Drive actuator has optional Configurator software for configuration and data viewing. When the\nConfigurator software is used, it must run on devices that are configured according to local security policies.\n Ensure that operation personnel are trained both on local security policies and the secure operation of the\neasy-Drive actuator.\nOperate the device within a controlled and secured physical environment.\n Operate the easy-Drive actuator and Configurator software within a controlled and secured network environment.\n Apply security patches and updates as they are released.\n. Report security incidents and potential product vulnerabilities.\n(https://go.emersonautomation.com/reportvulnerability_en)\n Follow local disposal policy for securely disposing of an unneeded device..", '2': '1. The temperature limits in the referenced tables and any applicable code or standard limitations should not be exceeded..\n2. Variation can be expected, based on temperature and pressure of application\n3. Actuator is capable of 14 of over-travel (104 of total travel) for travel stop adjustment and valve zeroing..\n4. Not compatible for use with valve assemblies that include a handwheel or manual actuator.\n5.Not intended for applications where process conditions could produce torque beyond the rated torque', '3': 'Table 2.Compatible Fisher Valve Types and Sizes for Square Shaft Connection\nSQUARE SHAFT CONNECTION SIZE\nVALVE TYPE\nVALVE SIZE, NPS\n(mm)\n1\n9\n1-1/2 and 2\n11\nV150,V150E.V200.andV300\n3 and 4\n14\n6\n19\n2\n9\n8580\n6\n19\n3\n11\n8580and8590\n4\n14', '1': ' ...

# %%
import json

def extract_topics_and_content(data):
    extracted_data = []

    def recurse_extract(json_object, current_topic=""):
        if isinstance(json_object, dict):
            for key, value in json_object.items():
                new_topic = f"{current_topic} {key}".strip()
                recurse_extract(value, new_topic)
        elif isinstance(json_object, str):
            extracted_data.append({"topic": current_topic, "content": json_object})
        elif isinstance(json_object, list):
            for item in json_object:
                recurse_extract(item, current_topic)

    recurse_extract(data)
    return extracted_data

# Load the JSON data
with open(topics_json_file_path, 'r') as f:
    data = json.load(f)

# Convert the data
converted_data = extract_topics_and_content(data)

# Print the converted data
# Save updated data back to JSON file
# with open(json_file_path, 'w') as json_file:
#     json.dump(nested_dict, json_file, indent=4)
print(json.dumps(converted_data, indent=4))
# Out:
# [
#     {
#         "topic": "Introduction Scope of Manual 1",
#         "content": "Scope of Manual\nA\nThis instruction manual provides installation, maintenance, and parts information for the easy-Drive.\n200R.Do not install, operate, or maintain an easy-Drive 2o0R without being fully trained and qualified in\nvalve, actuator, and accessory installation, operation, and maintenance.To avoid personal injury or\nproperty damage, it is important to carefully read, understand, and follow all the contents of this.\nmanual, including all safety cautions and warnings. If you have any questions about these instructions,\ncontact your Emerson sales officebefore proceeding.."
#     },
#     {
#         "topic": "Introduction Description 1",
#         "content": "Description\nThe easy-Drive 2ooR electric rotary actuators are used on rotary-shaft valve bodies for throttling or on-off applications\nThe 200R has an ISO 5211 mating interface that allows installation to non-Fisher valves. Style F mounting is available\nfor coupling with Fisher rotaryvalves.This actuator is ideal for use on pressure and flow control applications for Fisher\nVee-Ball NPS 1-6,HPBV NPS 2-4 and non-Fisher 90rotaryvalves with 9 mm,11 mm,14 mm,or 19 mm square shaft\nconnections, and 5/8-inch or 3/4-inch splined shaft connections. In applications that require a known loss of power\nposition, an RPU-100 can be used to drive the easy-Drive actuator open or closed.Consult the easy-Drive RPU-100\nInstruction Manual (D104551X012)"
#     },
#     {
#         "topic": "Introduction Specifications 4",
#         "content": "Instruction Manual\neasy-Drive 200R\nD104742X012\nApril 2024\nSpecifications\nTable 1 lists specifications for the easy-Drive 2o0R. Some of the specifications for a given actuator as it originally.\ncomes from the factory are stamped on a nameplate located on the lower actuator enclosure\nEducational Services\nEmerson Educational Services\nPhone: 1-800-338-8158\nE-mail: education@emerson.com\nemerson.com/mytraining\nSecurity\nNOTICE\nPhysical security is an important part of any security program and is fundamental to protecting your system..\nUnauthorized personnel may potentially cause significant damage to and/or misconfiguration of end users' equipment.\nThis could be intentional or unintentional and must be protected against by restricting access to unauthorized personnel in\nyour facility.\n If unsecured, any device in the field is vulnerable to a physical attack; safety and security procedures must include\nmitigation by physical security controls..\nThe easy-Drive actuator has optional Configurator software for configuration and data viewing. When the\nConfigurator software is used, it must run on devices that are configured according to local security policies.\n Ensure that operation personnel are trained both on local security policies and the secure operation of the\neasy-Drive actuator.\nOperate the device within a controlled and secured physical environment.\n Operate the easy-Drive actuator and Configurator software within a controlled and secured network environment.\n Apply security patches and updates as they are released.\n. Report security incidents and potential product vulnerabilities.\n(https://go.emersonautomation.com/reportvulnerability_en)\n Follow local disposal policy for securely disposing of an unneeded device.."
#     },
#     {
#         "topic": "Introduction Specifications 2",
#         "content": "1. The temperature limits in the referenced tables and any applicable code or standard limitations should not be exceeded..\n2. Variation can be expected, based on temperature and pressure of application\n3. Actuator is capable of 14 of over-travel (104 of total travel) for travel stop adjustment and valve zeroing..\n4. Not compatible for use with valve assemblies that include a handwheel or manual actuator.\n5.Not intended for applications where process conditions could produce torque beyond the rated torque"
#     },
#     {
#         "topic": "Introduction Specifications 3",
#         "content": "Table 2.Compatible Fisher Valve Types and Sizes for Square Shaft Connection\nSQUARE SHAFT CONNECTION SIZE\nVALVE TYPE\nVALVE SIZE, NPS\n(mm)\n1\n9\n1-1/2 and 2\n11\nV150,V150E.V200.andV300\n3 and 4\n14\n6\n19\n2\n9\n8580\n6\n19\n3\n11\n8580and8590\n4\n14"
#     },
#     {
#         "topic": "Introduction Specifications 1",
#         "content": "Table 1. Specifications\nMaterial Temperature Capabilities(1)\nTorque(5)\nElectric Actuator Assembly:\nRated:124 Nm1100 inlbf\n-40 to 70C-40 to 158F\nNominal Stroke Speed(2)\nAvailable Actuator Configurations(4)\n9 per second at 24 VDC\nPositioning\nHazardous Area Approvals\nCompatible Fisher Valve Types and Sizes\nCSA (C/Us): Explosion-Proof Class I, Division 1,\nSee tables 2 and 3\nGroupsC and DT6Ex db IIB T6Class I,Zone 1,\nAEx db IIB T6\nPower Requirements\nATEXFlameproof-Gas:\n11-30 VDC, minimum 2.7 amp power supply required\n2 G,Ex db IIB T6 Gb\n(fuse to 5 amps)\nIECEx Flameproof-Gas:Ex db IIB T6 Gb\nMaximum Current Draw\nEnclosure Rating\n2.3 amps\nType 4X and IP66\nIdle Current Draw\nDuty Cycle\n15 mA at 24 VDC\n50% maximum\n25 mA at 12 VDC\nConduit Connections\nEnclosure Material\nCast aluminum alloy with powder coat paint\nTwo 3/4 NPT connections\nTravel(3)\nApproximate Weight:\nRated: 1/4 turn, 90\n17.7 kg (39 lbs)"
#     },
#     {
#         "topic": "Introduction Educational Services 2",
#         "content": "Educational Services\nEmerson Educational Services\nPhone:1-800-338-8158\nE-mail:education@emerson.com\nemerson.com/mytraining"
#     },
#     {
#         "topic": "Introduction Educational Services 1",
#         "content": "easy-Drive 200R\nInstruction Manual\nApril 2024\nD104742X012\nTable 1. Specifications\nMaterial Temperature Capabilities(1)\nTorque(5)\nElectric Actuator Assembly:\nRated:124 Nm (1100 inlbf)\n-40 to 70C (-40 to 158F)\nNominal Stroke Speed(2)\nAvailable Actuator Configurations(4)\n9 per second at 24 VDC\nPositioning\nHazardous Area Approvals\nCompatible Fisher Valve Types and Sizes\nCSA (C/US): Explosion-Proof Class I, Division 1,\nSee tables 2 and 3\nGroupsC and D, T6, Ex db IIB T6,Class I, Zone 1\nAEx db IIB T6\nPower Requirements\nATEX Flameproof - Gas:\n11-30 VDC, minimum 2.7 amp power supply required\n2 GEx db IIB T6 Gb\n(fuse to 5 amps)\nIECEx Flameproof - Gas: Ex db IIB T6 Gb\nMaximum Current Draw\nEnclosure Rating\n2.3 amps\nType 4X and IP66\nIdle Current Draw\nDuty Cycle\n 15 mA at 24 VDC\n50% maximum\n 25 mA at 12 VDC\nEnclosure Material\nConduit Connections\nTwo 3/4 NPT connections\nCast aluminum alloy with powder coat paint\nTravel(3)\nApproximate Weight:\nRated: 1/4 turn, 90\n17.7 kg (39 lbs)\n1. The temperature limits in the referenced tables and any applicable code or standard limitations should not be exceeded.\n4. Not compatible for use with valve assemblies that include a handwheel or manual actuator.\n5. Not intended for applications where process conditions could produce torque beyond the rated torque..\nTable 2. Compatible Fisher Valve Types and Sizes for Square Shaft Connection\nSQUARE SHAFT CONNECTION SIZE\nVALVE TYPE\nVALVE SIZE, NPS\n(ww)\n1\n9\n1-1/2 and 2\n11\nV150, V150E, V200, andV300\n3 and 4\n14\n6\n19\n2\n6\n8580\n6\n19\n3\n11\n8580 and 8590\n14\n4\nTable 3. Compatible Fisher Valve Types and Sizes for Splined Shaft Connection (Retro-fit Only)(1)\nSPLINE SHAFT CONNECTION SIZE\nVALVE TYPE\nVALVE SIZE, NPS\n(Inch)\n1-1/2 and 2\n5/8\nV150, V150E, V200, and V300\n3 and 4\n3/4\n3\n5/8\n8580 and 8590\n4\n3/4\n1.Mounting bracket not supplied with splined shaft adaptor\n2"
#     },
#     {
#         "topic": "Introduction 2",
#         "content": "Figure 1.Fisher easy-Drive200R\neasy-Drive\nX1913"
#     },
#     {
#         "topic": "Introduction 1",
#         "content": "Fisher\" easy-Drive\" 200R"
#     },
#     {
#         "topic": "Security 1",
#         "content": "Security\nNOTICE\nPhysical security is an important part of any security program and is fundamental to protecting your system.\nUnauthorized personnel may potentially cause significant damage to and/or misconfiguration of end users'equipment.\nThis could be intentional or unintentional and must be protected against by restricting access to unauthorized personnel in\nyour facility.\nIf unsecured, any device in the field is vulnerable to a physical attack; safety and security procedures must include\nmitigation by physical security controls.\nThe easy-Drive actuator has optional Configurator software for configuration and data viewing.When the\nConfigurator software is used, it must run on devices that are configured according to local security policies\nEnsure that operation personnel are trained both on local security policies and the secure operation of the\neasy-Drive actuator.\nOperate the device within a controlled and secured physical environment.\nOperate the easy-Drive actuator and Configurator software within a controlled and secured network environment.\n. Apply security patches and updates as they are released.\nReport security incidents and potential product vulnerabilities\n(https://go.emersonautomation.com/reportvulnerability _en)\nFollow local disposal policy for securely disposing of an unneeded device"
#     },
#     {
#         "topic": "Installation Special Instructions for \u201cSafe Use\u201d and Installations in Hazardous Locations 1",
#         "content": "Special Instructions for \"Safe Use\" and Installations in Hazardous\nLocations\nAWARNING\nTo avoid static discharge from the enclosure, do not rub or clean the enclosure with solvents.To do so could result in an\nexplosion.Clean with a mild detergent and water only.\nThe enclosure is non-conducting and may generate an ignition-capable level of electrostatic charges under certain extreme\nconditions.The user should ensure that the equipment is not installed in a location where it may be subjected to external\nconditions (such as high-pressure steam) which might cause a build-up of electrostatic charges on non-conducting surfaces.\nAdditionally,cleaning ofthe equipment shall onlybe done with a damp cloth\nTo avoid damage to the enclosure,when screws are fully tightened into blind holes in enclosure walls,with no washer\nfitted,at least one full thread shall remain free at the base of the hole.\nFlame proof joints are not intended to be repaired.To ensure safe use in hazardous locations.do not attempt to repair the\nupper enclosure (key 3), lower enclosure (key 2) or output shaft assembly (key 5). Contact your Emerson sales office for\nmoreinformation."
#     },
#     {
#         "topic": "Installation Actuator Mounting Power Requirements 2",
#         "content": "Power\n1.Connect12or24VDCreference to:-\n2.Connect12 or24VDCpositive to:+\n3. Be sure to tighten terminals sufficiently to ensure solid mechanical connection"
#     },
#     {
#         "topic": "Installation Actuator Mounting Power Requirements 3",
#         "content": "Power\n1.Connect12 or 24 VDC reference to:-\n2.Connect12 or 24 VDC positive to:+\n3. Be sure to tighten terminals sufficiently to ensure solid mechanical connection."
#     },
#     {
#         "topic": "Installation Actuator Mounting Power Requirements 1",
#         "content": "easy-Drive 200R\nInstruction Manual\nApril 2024\nD104742X012\n1. Supply a method of supporting the weight of the valve and actuator during assembly..\n2. Manually rotate the valve shaft to the loss of signal position.\n3. Mount the easy-Drive 2o0R to the mounting kit designed and supplied by the user..\n4. Lift or hoist the actuator and mounting assembly onto the valve and mate the mounting kit securely to the valve\nfollowing the valve manufacturer's guidelines.\n5. Make the shaft connection between the actuator coupler and valve shaft.\na. When installing the user-supplied shaft connector the actuator shaft coupler should fully engage the valve shaft\nby a distance equal to or greater than the diameter of the actuator stem.\nNOTICE\nBe sure that the output shaft adaptor on the actuator and valve shaft are completely engaged. Do not attempt to remove\nthe shaft adaptor when force is applied to the shaft.\n6. Configure the actuator to the appropriate mode using the easy-Drive configurator tool. See Valve Type.\nConfiguration section of this manual.\n7. Externally adjustable travel stops are used to limit the degree of rotation at both ends of the actuator stroke to\ncalibrate valve to the actuator.\n8. Calibrate the actuator. See Calibration Instructions section of this manual..\nFigure 2. Fisher easy-Drive 200R\nCONTROLLER\nPOWER AND\nCONTROL TERMINAL\nOPTIONAL RESERVEE\nPOWERUNIT\nFIELDWIRING\nTERMINAL\nMOTOR AND GEAR CASE ASSEMBLY\nMOTOR ANDGEAR CASE ASSEMBLY\nINCLUDINGGEN2CONTROLBOARD\nANDRPU-100"
#     },
#     {
#         "topic": "Installation Actuator Mounting Wiring Instructions 1",
#         "content": "easy-Drive 200R\nInstruction Manual\nApril 2024\nD104742X012\nConnecting Using the Fisher easy-Drive Configuration Software\nThe Fisher easy-Drive Configurator software allows configuration and diagnosing of the Fisher easy-Drive electric\nactuator with a graphical interface. Connect a PC to the actuator using a serial or USB to RS-485 device using the wiring\ninstructions above. The UsB or serial device will be visible in the drop menu under Serial Port in the Manual Computer\nConnection settings. Address baud rate, parity, stop bits, and byte order should be set to the Modbus settings of the\nactuator. See Modbus Setup above for default actuator settings. Press the AUTO button in the upper left corner to\nattempt to scan for and enable from the Preferences in the upper right.\nUse the Fisher easy-Drive configuration software (figure 10) to make the desired changes, or register values may be.\nchanged to allow different functionality..\nValve Type Configuration\n Valve Type\nRotary: CW (clockwise to close)\nRotary: CCW (counterclockwise to close)\nFigure 11. Fisher easy-Drive Configuration Software\nAdvanced Settings\nWhen ttaching an eosyDrive Actuator to  new vole, you may need to chonge the\nactuator's valve type to motch the valve. The volve wi not operate correctly with a\nmismatched valve type\nVaive Type\nWARE\nD3\nCANCEL\nRotary:Cw\nRotary:CCW\n0.50Fixed\n0.62Fixed\n0.75Fixed\nStop-to-Stop\nThe easy-Drive 200R limits travel using hard stops that define the full range (max 104 rotation). Adjustable Travel.\nStops are provided to allow for adjustments to travel to meet the application requirements, and for valve\nalignment/calibration. See Actuator Mounting Section for more information on configuring the adjustable travel.\nstops.\n12"
#     },
#     {
#         "topic": "Installation Actuator Mounting 2",
#         "content": "1. Supply a method of supporting the weight of the valve and actuator during assembly\n2. Manually rotate the valve shaft to the loss of signal position.\n3. Mount the easy-Drive 2o0R to the mounting kit designed and supplied by the user.\n4. Lift or hoist the actuator and mounting assembly onto the valve and mate the mounting kit securely to the valve\nfollowing the valve manufacturer's guidelines.\n5.Make the shaft connection between the actuator coupler and valve shaft\na. When installing the user-supplied shaft connector the actuator shaft coupler should fully engage the valve shaft\nby a distance equal to or greater than the diameter of the actuator stem.\nNOTICE\nBe sure that the output shaft adaptor on the actuator and valve shaft are completely engaged.Do not attempt to remove\nthe shaft adaptor when force is applied to the shaft\n6. Configure the actuator to the appropriate mode using the easy-Drive configurator tool. See Valve Type\nConfiguration section of this manual.\n7. Externally adjustable travel stops are used to limit the degree of rotation at both ends of the actuator stroke to\ncalibrate valve to the actuator.\n8.Calibrate the actuator.See Calibration Instructions section of this manual."
#     },
#     {
#         "topic": "Installation Actuator Mounting 1",
#         "content": "Actuator Mounting\nThe following procedure describes how to mount an easy-Drive 2o0R actuator..\nStandalone actuators will be shipped with the shaft adaptor at the configured loss of signal position..\nUser designed and manufactured Mounting Kit and Stem Coupler will be needed to complete this procedure\nA WARNING\nAvoid personal injury from sudden release of process pressure or bursting of parts. Before performing any maintenance.\noperations:\nDo not remove the actuator from the valve while the valve is still pressurized.\nAlways wear protective gloves, clothing, and eyewear when performing any maintenance operations to avoid personal.\ninjury.\nDisconnect any operating lines providing air pressure, electric power, or a control signal to the actuator.Be sure the\nactuator cannot suddenly open or close the valve.\nUse bypass valves or completely shut off the process to isolate the valve from process pressure.Relieve process pressure\non both sides of the valve.Drain the process media from both sides of the valve.\nUse lock-out procedures to be sure that the above measures stay in effect while you work on the equipment.\nThe valve packing box may contain process fluids that are pressurized, even when the valve has been removed from the\n Check with your process or safety engineer for any additional measures that must be taken to protect against process.\nmedia.\nA WARNING\nTo avoid personal injury and equipment damage from moving parts, keep fingers and tools clear while stroking the\nactuator in the following steps.\nNOTICE\nTo avoid damage to the 2ooR actuator, do not install on a valve assembly that includes a handwheel or manual actuator."
#     },
#     {
#         "topic": "Installation 2",
#         "content": "AWARNING\nFor explosion-proof applications, ensure the actuator coveris properly bolted before applying power to the actuator\nPersonal injury or property damage may result from fire or explosion if power is applied to the actuator with the cover\nremoved in a hazardous area.Do not remove cover(s) or make live connections unless the area is known to be\nnon-hazardous.\nFor explosion-proof applications, install rigid metal conduit and a conduit seal no more than 457 mm (18 in) from the\nactuator.Personal injury or property damage may result from explosion if the seal is not installed.\nSelect wiring and/or cable glands that are rated for the environment of use (such ashazardous area,ingress protection, and\ntemperature).Failure to use properly rated wiring and/or cable glands can result in personal injury or property damage\nfrom fire or explosion.\nWiring connections must be in accordance with local, regional, and national codes for any given hazardous area approval.\nFailure to follow the local, regional, and national codes could result in personal injury or property damage from fire or\nexplosion."
#     },
#     {
#         "topic": "Installation 3",
#         "content": "AWARNING\nAvoid personal injury or property damage caused by possible actuator failure.The use of a rigidly-mounted support on the\nactuator casing may cause additional stress on the actuator leading to premature wear and/or failure of the actuator\ncomponents.\n1. The easy-Drive 2ooR can be installed in any position. Install the valve per the manufactuer's guidelines and per any.\napplicable local, regional, and national piping codes\n2. For explosion-proof applications, install rigid metal conduit and seal no more than 457 mm (18 in) from the\nactuator.\n3. Plastic conduit ports provided by factory are to be removed prior to operation and replaced with an explosion-proof\nport plug."
#     },
#     {
#         "topic": "Installation 1",
#         "content": "AWARNING\nAlways wear protective gloves, clothing, and eyewear when performing any installation operations to avoid personal\ninjury.\nTo avoid personal injury or property damage caused by bursting of pressure-retaining parts or by uncontrolled process.\nfluid, be certain the service conditions do not exceed the limits shown on the valve nameplate and in table 1. Use\npressure-relieving devices required by government or accepted industry codes and good engineering practices.\nCheck with your process or safety engineer for any additional measures that must be taken to protect against process\nmedia.\nIf installing into an existing application, also refer to the WARnING at the beginning of the Maintenance section in this\ninstruction manual."
#     }
# ]
